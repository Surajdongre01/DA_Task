# %%
import requests as rq

# %%
url = "https://www.hp.com/in-en/shop/laptops-tablets/latest-and-greatest.html"

# %%
rResp = rq.get(url)

# %%
rResp
# Out:
# <Response [200]>

# %%
rResp.text
# Out:
# '<!DOCTYPE html><html lang="en-in" class="ignore-hide"><head>\n      <style id="edgio-styles">\n        html body.hide-cookie-banner #onetrust-consent-sdk {\n          display: none !important;\n        }\n        html.ignore-hide, html.ignore-hide body.ignore-hide {\n          display: block !important;\n          opacity: 1 !important;\n          visibility: visible !important;\n        }\n        .page-header {\n          top: 0px !important;\n        }\n        .page-header.page-header-top #edgio-promo-banner-wrapper {\n            display: none !important;\n        }\n        .page-header .message.global.inside-notice {\n            position: relative;\n            margin-top: 0 !important;\n        }\n        .c-button.black-button {\n          background: #000000 !important;\n          line-height: 34px !important;\n          color: #ffffff !important;\n        }\n\n        .contact-us-container:not(.activated) {\n          display: none;\n        }\n        #edgio-placeholder
# ...

# %%
dcontent = rResp.content.decode("utf-8")

print(dcontent)
# Out:
# <!DOCTYPE html><html lang="en-in" class="ignore-hide"><head>
#       <style id="edgio-styles">
#         html body.hide-cookie-banner #onetrust-consent-sdk {
#           display: none !important;
#         }
#         html.ignore-hide, html.ignore-hide body.ignore-hide {
#           display: block !important;
#           opacity: 1 !important;
#           visibility: visible !important;
#         }
#         .page-header {
#           top: 0px !important;
#         }
#         .page-header.page-header-top #edgio-promo-banner-wrapper {
#             display: none !important;
#         }
#         .page-header .message.global.inside-notice {
#             position: relative;
#             margin-top: 0 !important;
#         }
#         .c-button.black-button {
#           background: #000000 !important;
#           line-height: 34px !important;
#           color: #ffffff !important;
#         }
#
#         .contact-us-container:not(.activated) {
#           display: none;
#         }
# ...

# %%
type(rResp.headers)
# Out:
# requests.structures.CaseInsensitiveDict

# %%
rHeader  = rResp.headers

print(rHeader)
# Out:
# {'Accept-Ranges': 'bytes', 'Cache-Control': 'max-age=0', 'Content-Type': 'text/html; charset=UTF-8', 'Expires': 'Tue, 28 May 2024 11:10:24 GMT', 'Last-Modified': 'Tue, 28 May 2024 11:03:10 GMT', 'router-header': 'edgio', 'Server': 'ECAcc (agb/52C1)', 'test-edgio': 'main-store-plp', 'test-origin-header': 'in-en-origin', 'Warning': '110 - "Response is stale"', 'x-content-security-policy': '', 'x-content-type-options': 'nosniff', 'x-edg-aws-region': 'ap-northeast-1', 'x-edg-components': 'pi=BufferProxyStack-975050324023-ap-northeast-1-ECSCluster-WBYuQT6EQGYi,p=1.39.2,w=7.10.2,wi=9430e69e-b52a-4132-a0c2-577d80e6d050', 'x-edg-mr': '207:5;207:39;207:41;207:756;207:757;207:808;', 'x-edg-platform-aws-account': '975050324023', 'x-edg-status': 'p=200,w=200', 'x-edg-version': '1265 207 193 7.10.2 2024-05-23T11:04:45Z 5b5a73a3-cf84-46a1-8c7f-f20abd57e646', 'x-hpols': '0.2d', 'x-request-id': '58426708212593645942363576602725186766', 'x-server': 'hpine', 'x-ua-compatible': 'IE=edge', 'x-webkit-csp
# ...

# %%
print(f'date = {rHeader['date']}')

print(f'Expires = {rHeader['Expires']}')
# Out:
# date = Tue, 28 May 2024 11:10:24 GMT
# Expires = Tue, 28 May 2024 11:10:24 GMT

# %%
userAgent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"

# %%
checkheader = rq.get(url,headers={'User-Agent' : userAgent})

# %%
print(checkheader)
# Out:
# <Response [200]>

# %%
checkheader.request.headers
# Out:
# {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}
